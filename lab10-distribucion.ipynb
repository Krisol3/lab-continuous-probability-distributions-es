# %% [markdown]
# # Antes de empezar:
#
#     Lee el archivo README.md
#     Comenta todo lo que puedas y utiliza los recursos (archivo README.md)
#     ¡Feliz aprendizaje!

# %% [markdown]
# En este ejercicio, generaremos números aleatorios a partir de las disribuciones continuas que aprendimos en la lección. Hay dos formas de generar números aleatorios:
#
# 1. Usando la librería numpy
# 1. Usando la librería Scipy
#
# Utiliza cualquiera de las dos librerías o ambas en este ejercicio.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Distribución Uniforme
#
# Para generar números aleatorios uniformes entre dos valores dados usando scipy, podemos usar el siguiente código o el código que hemos
# discutido en clase:

# %%
from scipy.stats import uniform

# %% [markdown]
# **Tarea:**
#
# 1. Basándote en el código anterior, escribe una función que genere números aleatorios uniformemente distribuidos. Hay varios requisitos para tu función:
#     * Debe aceptar 3 parámetros:
#         * `bottom` - el límite inferior de los números generados
#         * `ceiling` - el límite superior de los números generados
#         * `count` - cuántos números generar
#     * Debe devolver una matriz de números aleatorios distribuidos uniformemente
#
# 2. Llama a tu función con 2 conjuntos de parámetros a continuación:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 3. Traza las distribuciones uniformes generadas anteriormente utilizando histogramas, donde el eje x es el valor y el eje y es el recuento. Que el número de intervalos del histograma sea 10.
#
# El resultado debe ser como el siguiente:
#
# ![image.png](attachment:image.png)

# %%
def gen_random_num(bottom, ceiling, count):
    return np.random.uniform(low=bottom, high=ceiling, size=count)

# %%
dist_unif1 = gen_random_num(10, 15, 100)
#print(dist_unif1)
plt.figure(figsize=(8, 6))
plt.hist(dist_unif1, bins=10, color='skyblue', edgecolor='black')
plt.title('Histograma con valores de distribución uniforme 1')
plt.xlabel('Valor')
plt.ylabel('Recuento')
plt.show()

# %%
dist_unif2 = gen_random_num(10, 60, 1000)
#print(dist_unif2)
plt.figure(figsize=(8, 6))
plt.hist(dist_unif2, bins=10, color='skyblue', edgecolor='black')
plt.title('Histograma con valores de distribución uniforme 2')
plt.xlabel('Valor')
plt.ylabel('Recuento')
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# debido a la aleatoriedad de los números mostrados. Si queremos conseguir los mismos resultados al llamar a valores aleatorios, es necesario marcar una seed.

# %% [markdown]
# ## Distribución Normal
#
# 1. De la misma manera en el reto de Distribución Uniforme, escriba una función que genere números aleatorios distribuidos normalmente.
# 1. Genera 1.000 números distribuidos normalmente con media de 10 y desviación típica de 1
# 1. Genera 1.000 números distribuidos normalmente con una media de 10 y una desviación típica de 50
# 2. Representa gráficamente las distribuciones de los datos generados.
#
# Resultado esperado:
#
# ![image.png](attachment:image.png)

# %%
from scipy.stats import norm

# %%
def gen_random_num_normal(loc, scale, size):
    return np.random.normal(loc=0.0, scale=1.0, size=1000)

# %%
dist_norm1 = gen_random_num_normal(10, 1, 1000)
#print(dist_norm1)
plt.figure(figsize=(8, 6))
plt.hist(dist_norm1, bins=10, color='skyblue', edgecolor='black')
plt.title('Histograma con valores de distribución normal 1')
plt.xlabel('Valor')
plt.ylabel('Recuento')
plt.show()

# %%
dist_norm2 = gen_random_num_normal(10, 50, 1000)
#print(dist_norm2)
plt.figure(figsize=(8, 6))
plt.hist(dist_norm2, bins=10, color='skyblue', edgecolor='black')
plt.title('Histograma con valores dde distribución normal 2')
plt.xlabel('Valor')
plt.ylabel('Recuento')
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# # la diferencia en la desviación estandar repercute en la distancia de los valores respecto a la media,
# # por eso el segundo gráfico muestra una campana más ancha que el primero

# %% [markdown]
# ## Distribución Normal de Datos Reales
#
# En este reto vamos a echar un vistazo a los datos reales. Utilizaremos el archivo vehicles.csv para este ejercicio

# %%
vehicles = pd.read_csv('vehicles.csv')
vehicles
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %% [markdown]
# Primero importa vehicles.csv.
# A continuación, traza los histogramas de las siguientes variables:
#
# 1. Barriles de combustible/año

# %%
fuel_year = vehicles['Fuel Barrels/Year'].value_counts()
plt.figure(figsize=(8, 6))
plt.hist(fuel_year, bins=10, color='skyblue', edgecolor='black')
plt.title('Barriles de combustible/año')
plt.xlabel('Valor')
plt.ylabel('Recuento')
plt.show()

# %% [markdown]
# 2. Emisiones de CO2 Gramos/Milla

# %%
co2_m = vehicles['CO2 Emission Grams/Mile'].value_counts()
plt.figure(figsize=(8, 6))
plt.hist(co2_m, bins=10, color='skyblue', edgecolor='black')
plt.title('Emisiones de CO2/milla')
plt.xlabel('Valor')
plt.ylabel('Recuento')
plt.show()

# %% [markdown]
# 3. MPG combinado

# %%
mpg_c = vehicles['Combined MPG'].value_counts()
plt.figure(figsize=(8, 6))
plt.hist(mpg_c, bins=10, color='skyblue', edgecolor='black')
plt.title('MPG Combinado')
plt.xlabel('Valor')
plt.ylabel('Recuento')
plt.show()

# %% [markdown]
# ¿Cuál o cuáles de las variables tienen una distribución casi normal? ¿Cómo lo sabes?

# %%
# ninguna, porque la mayoria de valores no se encuentran en la media de los valores de la variable sino dentro del primer cuartil, en todos los casos.

# %% [markdown]
# Ninguno de ellos está normalmente ditribuido.

# %% [markdown]
# ## Distribución Exponencial

# %% [markdown]
# 1. Utilizando `numpy.random.exponential`, crea una función que devuelva una lista de números distribuidos exponencialmente con la media de 10.
#
# 1. Utiliza la función para generar dos secuencias de números de tamaño 10 y 100.
#
# 1. 2. Traza las distribuciones como histogramas con el número de bins como 100.
#
# El resultado debe ser como el siguiente:
#
# ![image.png](attachment:image.png)

# %%
def gen_random_exponential(scale, size):
    return np.random.exponential(scale=10, size=100)

# %%
dist_expo1 = gen_random_exponential(10,100)
#print(dist_expo1)
plt.figure(figsize=(8,6))
plt.hist(dist_expo1, bins=100, color='skyblue', edgecolor='black')
plt.title('Histograma con valores de distribución exponencial 1')
plt.show()

# %%
dist_expo2 = gen_random_exponential(10,10)
#print(dist_expo1)
plt.figure(figsize=(8,6))
plt.hist(dist_expo2, bins=100, color='skyblue', edgecolor='black')
plt.title('Histograma con valores de distribución exponencial 2')
plt.show()

# %% [markdown]
# ¿En qué se diferencian ambas distribuciones?

# %% [markdown]
# La media cambia, por lo que la distribución también cambia.

# %% [markdown]
# ## Distribución Exponencial de datos reales
#
# Supongamos que el tiempo que uno pasa en un banco se distribuye exponencialmente con media de 10 minutos (es decir, λ = 1/10). ¿Cuál es la probabilidad de que un cliente pase menos de quince minutos en el banco?
#
# Escribe un código en python para resolver este problema

# %%
n = 10
waiting_time = np.random.default_rng().exponential(scale=4, size=n)

x = ((waiting_time < 15).sum())/n 
y = ((waiting_time < 10).sum())/n
x-y
# Out:
# 0.0

# %%
# la probabilidad es de 0.09999999999999998

# %% [markdown]
# ¿Cuál es la probabilidad de que el cliente pase más de 15 minutos?

# %%
x = ((waiting_time > 15).sum())/n 
y = ((waiting_time < 10).sum())/n
x-y
# Out:
# -1.0
